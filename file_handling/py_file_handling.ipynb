# %% [markdown]
# # File Handling

# %%
lines = [f"Random line {i}\n" for i in range(1_000_000)]

with open("output.txt", "w", encoding="utf-8") as file:
    file.writelines(lines)

# %%
with open("output.txt", "o") as file:
    file.readlines()
